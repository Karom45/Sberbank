# %%
import pandas as pd
import time
import os
import json
import io
from collections import Counter
from os.path import join,isfile
from os import listdir
import dask
from fake_useragent import UserAgent
from SPARQLWrapper import SPARQLWrapper, JSON
import pandas as pd
import bookquery
ua = UserAgent()#Прокси

def counter_for_files(path):# Подсчет файлов в директории
    onlyfiles = [join(path, f) for f in listdir(path) if isfile(join(path, f))]
    return onlyfiles

# %%
def execute_query(qquery, entity_id):# Работа с запросами
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql",agent = ua.random)
    sparql.setQuery(qquery.format(entity_id = entity_id))
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return results['results']['bindings']

# %%
not_found = []

def find_entity(entity):
    path = join(os.getcwd() , r"Information\2\data\rus_labels")
    res = []
    dic = {}
    for top, dirs, files in os.walk(path):
        for f in files:
            file_path = join(path,f)
            exl = pd.read_csv(io.open(file_path, encoding='utf-8'), sep = ';', header = 0)
            entity_list = exl['entity'].tolist()
            if entity in entity_list:
                return f.split('_')[-1].split('.')[0], f.split('_')[1]
    global not_found
    not_found.append(entity)
    return None

# %%
# %%time
all_files = []
path = join(os.getcwd() , f'verified_files')
for top, dirs, files in os.walk(path): #проходимся по всем екселям (интентам)
    for f in files:
        count_x = 0
        intent_name = f.split('.')[0] #имя интента|имя файла
        exl = pd.read_excel(os.path.join(top, f)) #ексель блохина
        old_qid = exl[exl['Сущность #0 найдена правильно'] == 1]['QID #0'] #берем нужный столбец, неисправленное QID
        new_qid = exl[exl['Сущность #0 найдена правильно'] == 0]['Правильная сущность #0'] #исправленные QID
        qid = old_qid.tolist() + new_qid.tolist()
        res = []
        result = []
        exl_type = pd.read_excel(join(os.getcwd(),f'csv\Entities.xlsx')) #проверяем является ли сущность типом
        qid_type = exl_type[exl_type['subclass_weight'] == 2]['subclass']
        for i in qid:
            if i != 'x' and i != 'х':
                if i in qid_type.tolist(): #проверяем является ли сущность типом если да, сразу в res
                    type_lable = exl_type[exl_type['subclass'] == i]['subclass_label'].values[0]
                    a = (i, type_lable)
                    result.append(a)
                else:
                    result.append(find_entity(i))
            else:
                count_x += 1
        c = Counter()
        for i in result:
            c[i] += 1 
        all_files.append((c,intent_name, len(exl),count_x))
# Out:
# Wall time: 13min 27s

# %%
{item[1] : item[3] for item in all_files}
# Out:
# {'area': 0,
#  'borders_country': 0,
#  'capital': 0,
#  'country_by_capital': 1,
#  'height': 6,
#  'length': 2,
#  'max_by_area': 11,
#  'max_by_depth': 14,
#  'max_by_height': 3,
#  'max_by_length': 11,
#  'min_by_area': 4,
#  'population_count': 4}

# %%
name_dict = {"area" : "площадь(P2046)",
            "borders_country" : "имеет границы с(P47)",
            "capital" : "столица(P36)",
            "country_by_capital" : "является столицей(P1376)",
             "height":"высота над уровнем моря(P2044)",
             "length" : "длина(P2043)",
             "max_by_area":"площадь(P2046)",
             "max_by_depth":"глубина(P4511)",
             "max_by_height":"высота над уровнем моря(P2044)",
             "max_by_length" : "длина(P2043)",
             "min_by_area" : "площадь(P2046)",
            "population_count" : "население(P1082)"}
exl_file = pd.ExcelFile(join(os.getcwd() , f'Final analytics\\Analytics.xlsx'))
df = exl_file.parse(name_dict[all_files[0][1]])
df['global'] = 0
count_rows = 0
count_xx = 0
for items in all_files:
    del items[0][None]
#     print(items)
    qid_list = list(map(lambda x :x[0] , list(items[0].keys())))
    for k,v in df.iterrows():
        ind = list(df[df.subclass == v.subclass].index)[0]
        if v.subclass in qid_list:
            df.loc[ind,items[1]] = round(items[0][(v.subclass , v.subclass_label)]/items[2] * 100,2)
        else:
            df.loc[ind,items[1]] = "-"
new_row = {'subclass_label' : 'x' , 'subclass' : 'x'}
new_row.update({item[1] : round(item[3] * 100 /item[2],2) for item in all_files})
df = df.append(pd.DataFrame.from_dict([new_row], orient='columns', dtype=None, columns=None))
lst = ["subclass_label" , "subclass"]
lst.extend(list(name_dict.keys()))
df[lst].to_excel(r'Final analytics\new_Analytics.xlsx', sheet_name = 'analysis_by_intents' ,encoding='utf-8-sig' , index = False)

df = exl_file.parse(name_dict[all_files[0][1]])
df['global'] = 0
for items in all_files:
    count_rows += items[2]
    count_xx+= items[3]
#     print(items)
    qid_list = list(map(lambda x :x[0] , list(items[0].keys())))
    for k,v in df.iterrows():
        ind = list(df[df.subclass == v.subclass].index)[0]
        if v.subclass in qid_list:
            df.loc[ind,'global'] += items[0][(v.subclass , v.subclass_label)]
        else:
            df.loc[ind,'global'] += 0
df['global'] = round((df['global']/count_rows) * 100,2)
for k,v in df.iterrows():
    if v['global'] == 0:
        ind = list(df[df.subclass == v.subclass].index)[0]
        df.loc[ind,'global'] = '-'
print(count_rows)
print(count_xx)
new_row = {'subclass_label' : 'x' , 'subclass' : 'x', 'global' :round((count_xx/count_rows) * 100,2)}
df = df.append(pd.DataFrame.from_dict([new_row], orient='columns', dtype=None, columns=None))
lst = ["subclass_label" , "subclass" , "global"]
with pd.ExcelWriter(r'Final analytics\new_Analytics.xlsx' ,  engine="openpyxl" , mode  = 'a') as writer:
    df[lst].to_excel(writer, sheet_name = 'global_analysis' , encoding='utf-8-sig' , index = False)   
    
for items in all_files:
    del items[0][None]
    df = exl_file.parse(name_dict[items[1]])
#     print(items)
    qid_list = list(map(lambda x :x[0] , list(items[0].keys())))
    for k,v in df.iterrows():
        ind = list(df[df.subclass == v.subclass].index)[0]
        if v.subclass in qid_list:
            df.loc[ind,'Абсолютное значение'] = items[0][(v.subclass , v.subclass_label)]
            df.loc[ind,'Относительное значение , %'] = round(items[0][(v.subclass , v.subclass_label)]/items[2] * 100,2)
        else:
            df.loc[ind,'Абсолютное значение'] = '-'
            df.loc[ind,'Относительное значение , %'] = '-'
    new_row = {'subclass_label' : 'x' , 'subclass' : 'x', 'Встречаемость предиката для всех (%)' : '-' ,
               'Встречаемость предиката для популярных(%)': '-' , 'Абсолютное значение' : items[3] ,
               'Относительное значение , %' : round(items[3]* 100/items[2] , 2) }
    df = df.append(pd.DataFrame.from_dict([new_row], orient='columns', dtype=None, columns=None))
    for k,v in df.iterrows():
        ind = list(df[df.subclass == v.subclass].index)[0]
        if v['Абсолютное значение'] == 0:
            df.loc[ind,'Абсолютное значение'] = '-'
        if v['Относительное значение , %'] == 0:
            df.loc[ind,'Относительное значение , %'] = '-'
    with pd.ExcelWriter(r'Final analytics\new_Analytics.xlsx' ,  engine="openpyxl" , mode  = 'a') as writer:
        df.to_excel(writer, sheet_name = items[1] , encoding='utf-8-sig' , index = False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# 3514
# 56

# %%
ua = UserAgent()
res = []
bad_requests = []

def execute_query(qquery, entity_id):
    sparql = SPARQLWrapper("https://query.wikidata.org/sparql", agent = ua.random)
    sparql.setQuery(qquery.format(entity_id = entity_id))
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    return results['results']['bindings']

def entities_sparqul(entity, f = 0):
        entities = {}
        res = []
        s = ''
        if f > 3:
            global bad_requests
            bad_requests.append(entity)
            print('Bad request ', entity)
            return None
        try:
            raw_results = execute_query(bookquery.subclass_of, entity)
            if raw_results != []:
                entities['entity_id'] = raw_results[0]['show']['value'].split('/')[-1]
                entities['entity_label'] = raw_results[0]['showLabel']['value']
                for r in raw_results:
                    subclass = r['subclass']['value'].split('/')[-1]
                    subclass_label = r['subclassLabel']['value']
                    s += subclass + '_' + subclass_label + ','
                entities['subclass'] = s
            else:
                raw_results = execute_query(bookquery.subclass_name, entity)
                
                entities['entity_id'] = raw_results[0]['show']['value'].split('/')[-1]
                entities['entity_label'] = raw_results[0]['showLabel']['value']
                entities['subclass'] = s
            print(entities)
            res.append(entities)
            return entities #pd.DataFrame(data = res, columns = ['entity_id', 'entity_label', 'subclass'])
        except Exception as e:
            time.sleep(5)
            print(f'Exception in {entity}: {e}')
            return entities_sparqul(entity, f + 1)

# %%
print(len(not_found))
# Out:
# 534

# %%
res = []
for i in not_found:
    if i != 'x' or i != 'х':
        res.append(entities_sparqul(i))
res
# Out:
# {'entity_id': 'Q61', 'entity_label': 'Вашингтон', 'subclass': 'Q5119_столица,Q475050_федеральный округ,Q1093829_большой город в США,Q1549591_город с населением более 100 000 человек,'}
# {'entity_id': 'Q223', 'entity_label': 'Гренландия', 'subclass': 'Q192611_избирательный округ,Q66724388_страна в составе Королевства Дании,'}
# {'entity_id': 'Q8652', 'entity_label': 'Майами', 'subclass': 'Q1093829_большой город в США,'}
# {'entity_id': 'Q1353', 'entity_label': 'Дели', 'subclass': 'Q174844_мега-город,Q467745_союзные территории Индии,Q1637706_город-миллионер,'}
# {'entity_id': 'Q223', 'entity_label': 'Гренландия', 'subclass': 'Q192611_избирательный округ,Q66724388_страна в составе Королевства Дании,'}
# {'entity_id': 'Q223', 'entity_label': 'Гренландия', 'subclass': 'Q192611_избирательный округ,Q66724388_страна в составе Королевства Дании,'}
# {'entity_id': 'Q223', 'entity_label': 'Гренландия', 'subclass': 'Q192611_избирательный округ,Q66724388_страна в составе Королевства Дании,'}
# {'entity_id': 'Q5401', 'entity_label': 'Евразия', 'subclass': 'Q55833_суперконтинент,'}
# {'entity_id': 'Q4504093', 'entity_label': 'Средняя полоса России', 'subclass': 'Q151885_понятие,'}
# {'entity_id': 'Q2', 'entity_label': 'Земля', 'subclass': 'Q3504248_внутренняя планета,'}
# {'entity_id': 'Q5401', 'entity_label': 'Евразия', 'subclass': 'Q55833_суперконтинент,'}
# {'entity_id': 'Q179970', 'entity_label': 'Эйр-Норт', 'subclass': 'Q9019918_бессточное озеро,'}
# {'entity_id': 'Q2', 'entity_label': 'Земля', 'subclass': 'Q3504248_внутренняя планета,'}
# {'entity_id': 'Q102217', 'entity_label': 'Витебск', 'subclass': 'Q1549591_город с населением более 100 000 человек,Q79323854_город областного подчинения,'}
# {'entity_id': 'Q383093', 'entity_label': 'Северо-Западный федеральный округ', 'subclass': 'Q484215_федеральный округ России,'}
# {'entity_id': 'Q5401', 'entity_label': 'Евразия', 'subclass': 'Q55833_суперконтинент,'}
# {'entity_id': 'Q2678', 'entity_label': 'Гомель', 'subclass': 'Q1549591_город с населением более 100 000 человек,Q79323854_город областного подчинения,'}
# {'entity_id': 'Q82931', 'entity_label': 'Коралловое море', 'subclass': 'Q204894_Окраинное море,'}
# {'entity_id': 'Q125309', 'entity_label': 'Чад', 'subclass': 'Q9019918_бессточное озеро,'}
# {'entity_id': 'Q5484', 'entity_label': 'Каспийское море', 'subclass': 'Q15324_водный объект,Q188025_минеральное озеро,Q9019918_бессточное озеро,'}
# {'entity_id': 'Q44133', 'entity_label': 'Белое море', 'subclass': 'Q204894_Окраинное море,'}
# {'entity_id': 'Q201294', 'entity_label': 'Кукунор', 'subclass': 'Q9019918_бессточное озеро,'}
# {'entity_id': 'Q134485', 'entity_label': 'Балхаш', 'subclass': 'Q9019918_бессточное озеро,'}
# {'entity_id': 'Q35883', 'entity_label': 'Аральское море', 'subclass': 'Q47486890_бывшее озеро,'}
# {'entity_id': 'Q69564', 'entity_label': 'тайга', 'subclass': 'Q101998_биом,Q2083910_растительная формация,'}
# {'entity_id': 'Q11081619', 'entity_label': 'суша', 'subclass': ''}
# {'entity_id': 'Q1774', 'entity_label': 'Занзибар', 'subclass': 'Q486972_населённый пункт,'}
# {'entity_id': 'Q33946', 'entity_label': 'Чехословакия', 'subclass': 'Q3024240_историческое государство,'}
# {'entity_id': 'Q31354462', 'entity_label': 'Республика Абхазия', 'subclass': 'Q15634554_непризнанное либо частично признанное государство,'}
# {'entity_id': 'Q31354462', 'entity_label': 'Республика Абхазия', 'subclass': 'Q15634554_непризнанное либо частично признанное государство,'}
# {'entity_id': 'Q9248', 'entity_label': 'Баку', 'subclass': 'Q5119_столица,Q137413_административно-территориальное деление Азербайджана,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,'}
# {'entity_id': 'Q33946', 'entity_label': 'Чехословакия', 'subclass': 'Q3024240_историческое государство,'}
# {'entity_id': 'Q31354462', 'entity_label': 'Республика Абхазия', 'subclass': 'Q15634554_непризнанное либо частично признанное государство,'}
# {'entity_id': 'Q3125978', 'entity_label': 'Бали', 'subclass': 'Q5098_провинция Индонезии,'}
# {'entity_id': 'Q82112', 'entity_label': 'Мехико', 'subclass': 'Q15149663_штат Мексики,'}
# {'entity_id': 'Q1786286', 'entity_label': 'Кубанская область', 'subclass': 'Q7075127_область Российской империи,'}
# {'entity_id': 'Q1764', 'entity_label': 'Рейкьявик', 'subclass': 'Q515_город,Q5119_столица,Q955655_община Исландии,Q1549591_город с населением более 100 000 человек,Q2264924_портовый город,Q51929311_первый по величине город,'}
# {'entity_id': 'Q61', 'entity_label': 'Вашингтон', 'subclass': 'Q5119_столица,Q475050_федеральный округ,Q1093829_большой город в США,Q1549591_город с населением более 100 000 человек,'}
# {'entity_id': 'Q61', 'entity_label': 'Вашингтон', 'subclass': 'Q5119_столица,Q475050_федеральный округ,Q1093829_большой город в США,Q1549591_город с населением более 100 000 человек,'}
# {'entity_id': 'Q2868', 'entity_label': 'Лима', 'subclass': 'Q5119_столица,'}
# {'entity_id': 'Q1764', 'entity_label': 'Рейкьявик', 'subclass': 'Q515_город,Q5119_столица,Q955655_община Исландии,Q1549591_город с населением более 100 000 человек,Q2264924_портовый город,Q51929311_первый по величине город,'}
# {'entity_id': 'Q1335', 'entity_label': 'Монтевидео', 'subclass': 'Q5119_столица,'}
# {'entity_id': 'Q34692', 'entity_label': 'Кингстон', 'subclass': 'Q515_город,Q5119_столица,Q1549591_город с населением более 100 000 человек,'}
# {'entity_id': 'Q85', 'entity_label': 'Каир', 'subclass': 'Q5119_столица,'}
# {'entity_id': 'Q1353', 'entity_label': 'Дели', 'subclass': 'Q174844_мега-город,Q467745_союзные территории Индии,Q1637706_город-миллионер,'}
# {'entity_id': 'Q85', 'entity_label': 'Каир', 'subclass': 'Q5119_столица,'}
# {'entity_id': 'Q61', 'entity_label': 'Вашингтон', 'subclass': 'Q5119_столица,Q475050_федеральный округ,Q1093829_большой город в США,Q1549591_город с населением более 100 000 человек,'}
# {'entity_id': 'Q61', 'entity_label': 'Вашингтон', 'subclass': 'Q5119_столица,Q475050_федеральный округ,Q1093829_большой город в США,Q1549591_город с населением более 100 000 человек,'}
# {'entity_id': 'Q61', 'entity_label': 'Вашингтон', 'subclass': 'Q5119_столица,Q475050_федеральный округ,Q1093829_большой город в США,Q1549591_город с населением более 100 000 человек,'}
# {'entity_id': 'Q61', 'entity_label': 'Вашингтон', 'subclass': 'Q5119_столица,Q475050_федеральный округ,Q1093829_большой город в США,Q1549591_город с населением более 100 000 человек,'}
# {'entity_id': 'Q61', 'entity_label': 'Вашингтон', 'subclass': 'Q5119_столица,Q475050_федеральный округ,Q1093829_большой город в США,Q1549591_город с населением более 100 000 человек,'}
# {'entity_id': 'Q61', 'entity_label': 'Вашингтон', 'subclass': 'Q5119_столица,Q475050_федеральный округ,Q1093829_большой город в США,Q1549591_город с населением более 100 000 человек,'}
# {'entity_id': 'Q61', 'entity_label': 'Вашингтон', 'subclass': 'Q5119_столица,Q475050_федеральный округ,Q1093829_большой город в США,Q1549591_город с населением более 100 000 человек,'}
# {'entity_id': 'Q61', 'entity_label': 'Вашингтон', 'subclass': 'Q5119_столица,Q475050_федеральный округ,Q1093829_большой город в США,Q1549591_город с населением более 100 000 человек,'}
# {'entity_id': 'Q61', 'entity_label': 'Вашингтон', 'subclass': 'Q5119_столица,Q475050_федеральный округ,Q1093829_большой город в США,Q1549591_город с населением более 100 000 человек,'}
# {'entity_id': 'Q2868', 'entity_label': 'Лима', 'subclass': 'Q5119_столица,'}
# {'entity_id': 'Q2868', 'entity_label': 'Лима', 'subclass': 'Q5119_столица,'}
# {'entity_id': 'Q1764', 'entity_label': 'Рейкьявик', 'subclass': 'Q515_город,Q5119_столица,Q955655_община Исландии,Q1549591_город с населением более 100 000 человек,Q2264924_портовый город,Q51929311_первый по величине город,'}
# {'entity_id': 'Q61', 'entity_label': 'Вашингтон', 'subclass': 'Q5119_столица,Q475050_федеральный округ,Q1093829_большой город в США,Q1549591_город с населением более 100 000 человек,'}
# {'entity_id': 'Q61', 'entity_label': 'Вашингтон', 'subclass': 'Q5119_столица,Q475050_федеральный округ,Q1093829_большой город в США,Q1549591_город с населением более 100 000 человек,'}
# {'entity_id': 'Q2868', 'entity_label': 'Лима', 'subclass': 'Q5119_столица,'}
# {'entity_id': 'Q2868', 'entity_label': 'Лима', 'subclass': 'Q5119_столица,'}
# {'entity_id': 'Q1335', 'entity_label': 'Монтевидео', 'subclass': 'Q5119_столица,'}
# {'entity_id': 'Q1781', 'entity_label': 'Будапешт', 'subclass': 'Q5119_столица,Q171441_Анклав,Q618123_географический объект,Q1637706_город-миллионер,Q13218690_город в Венгрии,'}
# {'entity_id': 'Q3915', 'entity_label': 'Антананариву', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,'}
# {'entity_id': 'Q597', 'entity_label': 'Лиссабон', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q13217644_муниципалитет Португалии,Q15647906_город Португалии,'}
# {'entity_id': 'Q1844', 'entity_label': 'Вадуц', 'subclass': 'Q5119_столица,Q203300_муниципалитет Лихтенштейна,Q902814_граничный город,'}
# {'entity_id': 'Q987', 'entity_label': 'Нью-Дели', 'subclass': 'Q5119_столица,Q1149652_округ Индии,Q1549591_город с населением более 100 000 человек,'}
# {'entity_id': 'Q3640', 'entity_label': 'Анкара', 'subclass': 'Q5119_столица,Q1637706_город-миллионер,Q2716259_metropolitan municipality in Turkey,Q50330360_второй по величине город,'}
# {'entity_id': 'Q23430', 'entity_label': 'Улан-Батор', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q10864048_административная единица первого уровня,'}
# {'entity_id': 'Q2844', 'entity_label': 'Бразилиа', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q3184121_муниципалитет Бразилии,'}
# {'entity_id': 'Q2907', 'entity_label': 'Сукре', 'subclass': 'Q5119_столица,Q676050_исторический центр города,Q1062710_муниципалитет в Боливии,Q1549591_город с населением более 100 000 человек,'}
# {'entity_id': 'Q1085', 'entity_label': 'Прага', 'subclass': 'Q5119_столица,Q38911_край Чехии,Q171441_Анклав,Q192611_избирательный округ,Q548611_район Чехии,Q1549591_город с населением более 100 000 человек,Q5153359_община Чехии,Q7819319_населённый пункт с расширенными полномочиями,Q7841907_municipality with authorized municipal office,Q8452914_district town,Q12031379_capital of region,Q15978299_муниципалитет со статусом города,Q76007695_administrative district of Czech municipality with expanded powers,Q76009696_administrative district of Czech municipality with authorized municipal office,'}
# {'entity_id': 'Q9248', 'entity_label': 'Баку', 'subclass': 'Q5119_столица,Q137413_административно-территориальное деление Азербайджана,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,'}
# {'entity_id': 'Q1930', 'entity_label': 'Оттава', 'subclass': 'Q5119_столица,Q486972_населённый пункт,Q1549591_город с населением более 100 000 человек,Q14762300_одноуровневый муниципалитет Онтарио,Q17457753_census subdivision,'}
# {'entity_id': 'Q1085', 'entity_label': 'Прага', 'subclass': 'Q5119_столица,Q38911_край Чехии,Q171441_Анклав,Q192611_избирательный округ,Q548611_район Чехии,Q1549591_город с населением более 100 000 человек,Q5153359_община Чехии,Q7819319_населённый пункт с расширенными полномочиями,Q7841907_municipality with authorized municipal office,Q8452914_district town,Q12031379_capital of region,Q15978299_муниципалитет со статусом города,Q76007695_administrative district of Czech municipality with expanded powers,Q76009696_administrative district of Czech municipality with authorized municipal office,'}
# {'entity_id': 'Q3861', 'entity_label': 'Доха', 'subclass': 'Q5119_столица,Q685320_община Катара,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,'}
# {'entity_id': 'Q1773', 'entity_label': 'Рига', 'subclass': 'Q5119_столица,Q15127838_город республиканского подчинения,'}
# {'entity_id': 'Q19660', 'entity_label': 'Бухарест', 'subclass': 'Q5119_столица,Q640364_муниципии Румынии,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q10864048_административная единица первого уровня,'}
# {'entity_id': 'Q1489', 'entity_label': 'Мехико', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q20528428_federative entity of Mexico,'}
# {'entity_id': 'Q8684', 'entity_label': 'Сеул', 'subclass': 'Q5119_столица,Q1637706_город-миллионер,Q7574799_special city of South Korea,'}
# {'entity_id': 'Q1863', 'entity_label': 'Андорра-ла-Велья', 'subclass': 'Q5119_столица,'}
# {'entity_id': 'Q3915', 'entity_label': 'Антананариву', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,'}
# {'entity_id': 'Q1748', 'entity_label': 'Копенгаген', 'subclass': 'Q5119_столица,'}
# {'entity_id': 'Q1781', 'entity_label': 'Будапешт', 'subclass': 'Q5119_столица,Q171441_Анклав,Q618123_географический объект,Q1637706_город-миллионер,Q13218690_город в Венгрии,'}
# {'entity_id': 'Q1953', 'entity_label': 'Ереван', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q10864048_административная единица первого уровня,Q20724701_город в Армении,'}
# {'entity_id': 'Q3718', 'entity_label': 'Дакар', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q2264924_портовый город,Q15253706_город,'}
# {'entity_id': 'Q3640', 'entity_label': 'Анкара', 'subclass': 'Q5119_столица,Q1637706_город-миллионер,Q2716259_metropolitan municipality in Turkey,Q50330360_второй по величине город,'}
# {'entity_id': 'Q1085', 'entity_label': 'Прага', 'subclass': 'Q5119_столица,Q38911_край Чехии,Q171441_Анклав,Q192611_избирательный округ,Q548611_район Чехии,Q1549591_город с населением более 100 000 человек,Q5153359_община Чехии,Q7819319_населённый пункт с расширенными полномочиями,Q7841907_municipality with authorized municipal office,Q8452914_district town,Q12031379_capital of region,Q15978299_муниципалитет со статусом города,Q76007695_administrative district of Czech municipality with expanded powers,Q76009696_administrative district of Czech municipality with authorized municipal office,'}
# {'entity_id': 'Q8684', 'entity_label': 'Сеул', 'subclass': 'Q5119_столица,Q1637706_город-миллионер,Q7574799_special city of South Korea,'}
# {'entity_id': 'Q406', 'entity_label': 'Стамбул', 'subclass': 'Q5119_столица,Q174844_мега-город,Q1200957_туристическое направление,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q2264924_портовый город,Q2716259_metropolitan municipality in Turkey,Q27554677_бывшая столица,Q51929311_первый по величине город,'}
# {'entity_id': 'Q3616', 'entity_label': 'Тегеран', 'subclass': 'Q5119_столица,Q200250_метрополис,Q208511_глобальный город,Q1637706_город-миллионер,Q56557504_город Ирана,'}
# {'entity_id': 'Q9361', 'entity_label': 'Бишкек', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q10864048_административная единица первого уровня,Q15623974_административно-территориальное деление Киргизии,'}
# {'entity_id': 'Q9248', 'entity_label': 'Баку', 'subclass': 'Q5119_столица,Q137413_административно-территориальное деление Азербайджана,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,'}
# {'entity_id': 'Q1773', 'entity_label': 'Рига', 'subclass': 'Q5119_столица,Q15127838_город республиканского подчинения,'}
# {'entity_id': 'Q1085', 'entity_label': 'Прага', 'subclass': 'Q5119_столица,Q38911_край Чехии,Q171441_Анклав,Q192611_избирательный округ,Q548611_район Чехии,Q1549591_город с населением более 100 000 человек,Q5153359_община Чехии,Q7819319_населённый пункт с расширенными полномочиями,Q7841907_municipality with authorized municipal office,Q8452914_district town,Q12031379_capital of region,Q15978299_муниципалитет со статусом города,Q76007695_administrative district of Czech municipality with expanded powers,Q76009696_administrative district of Czech municipality with authorized municipal office,'}
# {'entity_id': 'Q19660', 'entity_label': 'Бухарест', 'subclass': 'Q5119_столица,Q640364_муниципии Румынии,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q10864048_административная единица первого уровня,'}
# {'entity_id': 'Q70', 'entity_label': 'Берн', 'subclass': 'Q5119_столица,Q56061_административно-территориальная единица,Q70208_община Швейцарии,Q537250_федеральный город,Q1187811_университетский город,Q1549591_город с населением более 100 000 человек,Q14770218_столица швейцарского кантона,Q54935504_город Швейцарии,'}
# {'entity_id': 'Q406', 'entity_label': 'Стамбул', 'subclass': 'Q5119_столица,Q174844_мега-город,Q1200957_туристическое направление,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q2264924_портовый город,Q2716259_metropolitan municipality in Turkey,Q27554677_бывшая столица,Q51929311_первый по величине город,'}
# {'entity_id': 'Q8684', 'entity_label': 'Сеул', 'subclass': 'Q5119_столица,Q1637706_город-миллионер,Q7574799_special city of South Korea,'}
# {'entity_id': 'Q1953', 'entity_label': 'Ереван', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q10864048_административная единица первого уровня,Q20724701_город в Армении,'}
# {'entity_id': 'Q1489', 'entity_label': 'Мехико', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q20528428_federative entity of Mexico,'}
# {'entity_id': 'Q2844', 'entity_label': 'Бразилиа', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q3184121_муниципалитет Бразилии,'}
# {'entity_id': 'Q1085', 'entity_label': 'Прага', 'subclass': 'Q5119_столица,Q38911_край Чехии,Q171441_Анклав,Q192611_избирательный округ,Q548611_район Чехии,Q1549591_город с населением более 100 000 человек,Q5153359_община Чехии,Q7819319_населённый пункт с расширенными полномочиями,Q7841907_municipality with authorized municipal office,Q8452914_district town,Q12031379_capital of region,Q15978299_муниципалитет со статусом города,Q76007695_administrative district of Czech municipality with expanded powers,Q76009696_administrative district of Czech municipality with authorized municipal office,'}
# {'entity_id': 'Q23430', 'entity_label': 'Улан-Батор', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q10864048_административная единица первого уровня,'}
# {'entity_id': 'Q8684', 'entity_label': 'Сеул', 'subclass': 'Q5119_столица,Q1637706_город-миллионер,Q7574799_special city of South Korea,'}
# {'entity_id': 'Q9248', 'entity_label': 'Баку', 'subclass': 'Q5119_столица,Q137413_административно-территориальное деление Азербайджана,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,'}
# {'entity_id': 'Q1489', 'entity_label': 'Мехико', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q20528428_federative entity of Mexico,'}
# {'entity_id': 'Q9361', 'entity_label': 'Бишкек', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q10864048_административная единица первого уровня,Q15623974_административно-территориальное деление Киргизии,'}
# {'entity_id': 'Q406', 'entity_label': 'Стамбул', 'subclass': 'Q5119_столица,Q174844_мега-город,Q1200957_туристическое направление,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q2264924_портовый город,Q2716259_metropolitan municipality in Turkey,Q27554677_бывшая столица,Q51929311_первый по величине город,'}
# {'entity_id': 'Q3640', 'entity_label': 'Анкара', 'subclass': 'Q5119_столица,Q1637706_город-миллионер,Q2716259_metropolitan municipality in Turkey,Q50330360_второй по величине город,'}
# {'entity_id': 'Q3915', 'entity_label': 'Антананариву', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,'}
# {'entity_id': 'Q987', 'entity_label': 'Нью-Дели', 'subclass': 'Q5119_столица,Q1149652_округ Индии,Q1549591_город с населением более 100 000 человек,'}
# {'entity_id': 'Q1085', 'entity_label': 'Прага', 'subclass': 'Q5119_столица,Q38911_край Чехии,Q171441_Анклав,Q192611_избирательный округ,Q548611_район Чехии,Q1549591_город с населением более 100 000 человек,Q5153359_община Чехии,Q7819319_населённый пункт с расширенными полномочиями,Q7841907_municipality with authorized municipal office,Q8452914_district town,Q12031379_capital of region,Q15978299_муниципалитет со статусом города,Q76007695_administrative district of Czech municipality with expanded powers,Q76009696_administrative district of Czech municipality with authorized municipal office,'}
# {'entity_id': 'Q70', 'entity_label': 'Берн', 'subclass': 'Q5119_столица,Q56061_административно-территориальная единица,Q70208_община Швейцарии,Q537250_федеральный город,Q1187811_университетский город,Q1549591_город с населением более 100 000 человек,Q14770218_столица швейцарского кантона,Q54935504_город Швейцарии,'}
# {'entity_id': 'Q1761', 'entity_label': 'Дублин', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q13455645_административный город Республики Ирландия,'}
# {'entity_id': 'Q2844', 'entity_label': 'Бразилиа', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q3184121_муниципалитет Бразилии,'}
# {'entity_id': 'Q3870', 'entity_label': 'Найроби', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q3976641_Административное деление Кении,'}
# {'entity_id': 'Q1865', 'entity_label': 'Куала-Лумпур', 'subclass': 'Q5119_столица,Q1008803_федеральная территория Малайзии,Q1637706_город-миллионер,'}
# {'entity_id': 'Q5465', 'entity_label': 'Кейптаун', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q2264924_портовый город,Q15042037_статистическая область,'}
# {'entity_id': 'Q1461', 'entity_label': 'Манила', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q29946056_сильно урбанизированный город,'}
# {'entity_id': 'Q8684', 'entity_label': 'Сеул', 'subclass': 'Q5119_столица,Q1637706_город-миллионер,Q7574799_special city of South Korea,'}
# {'entity_id': 'Q1761', 'entity_label': 'Дублин', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q13455645_административный город Республики Ирландия,'}
# {'entity_id': 'Q3640', 'entity_label': 'Анкара', 'subclass': 'Q5119_столица,Q1637706_город-миллионер,Q2716259_metropolitan municipality in Turkey,Q50330360_второй по величине город,'}
# {'entity_id': 'Q406', 'entity_label': 'Стамбул', 'subclass': 'Q5119_столица,Q174844_мега-город,Q1200957_туристическое направление,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q2264924_портовый город,Q2716259_metropolitan municipality in Turkey,Q27554677_бывшая столица,Q51929311_первый по величине город,'}
# {'entity_id': 'Q1489', 'entity_label': 'Мехико', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q20528428_federative entity of Mexico,'}
# {'entity_id': 'Q70', 'entity_label': 'Берн', 'subclass': 'Q5119_столица,Q56061_административно-территориальная единица,Q70208_община Швейцарии,Q537250_федеральный город,Q1187811_университетский город,Q1549591_город с населением более 100 000 человек,Q14770218_столица швейцарского кантона,Q54935504_город Швейцарии,'}
# {'entity_id': 'Q2844', 'entity_label': 'Бразилиа', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q3184121_муниципалитет Бразилии,'}
# {'entity_id': 'Q1930', 'entity_label': 'Оттава', 'subclass': 'Q5119_столица,Q486972_населённый пункт,Q1549591_город с населением более 100 000 человек,Q14762300_одноуровневый муниципалитет Онтарио,Q17457753_census subdivision,'}
# {'entity_id': 'Q1085', 'entity_label': 'Прага', 'subclass': 'Q5119_столица,Q38911_край Чехии,Q171441_Анклав,Q192611_избирательный округ,Q548611_район Чехии,Q1549591_город с населением более 100 000 человек,Q5153359_община Чехии,Q7819319_населённый пункт с расширенными полномочиями,Q7841907_municipality with authorized municipal office,Q8452914_district town,Q12031379_capital of region,Q15978299_муниципалитет со статусом города,Q76007695_administrative district of Czech municipality with expanded powers,Q76009696_administrative district of Czech municipality with authorized municipal office,'}
# {'entity_id': 'Q9361', 'entity_label': 'Бишкек', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q10864048_административная единица первого уровня,Q15623974_административно-территориальное деление Киргизии,'}
# {'entity_id': 'Q23661', 'entity_label': 'Веллингтон', 'subclass': 'Q5119_столица,'}
# {'entity_id': 'Q597', 'entity_label': 'Лиссабон', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q13217644_муниципалитет Португалии,Q15647906_город Португалии,'}
# {'entity_id': 'Q1748', 'entity_label': 'Копенгаген', 'subclass': 'Q5119_столица,'}
# {'entity_id': 'Q987', 'entity_label': 'Нью-Дели', 'subclass': 'Q5119_столица,Q1149652_округ Индии,Q1549591_город с населением более 100 000 человек,'}
# {'entity_id': 'Q70', 'entity_label': 'Берн', 'subclass': 'Q5119_столица,Q56061_административно-территориальная единица,Q70208_община Швейцарии,Q537250_федеральный город,Q1187811_университетский город,Q1549591_город с населением более 100 000 человек,Q14770218_столица швейцарского кантона,Q54935504_город Швейцарии,'}
# {'entity_id': 'Q70', 'entity_label': 'Берн', 'subclass': 'Q5119_столица,Q56061_административно-территориальная единица,Q70208_община Швейцарии,Q537250_федеральный город,Q1187811_университетский город,Q1549591_город с населением более 100 000 человек,Q14770218_столица швейцарского кантона,Q54935504_город Швейцарии,'}
# {'entity_id': 'Q8684', 'entity_label': 'Сеул', 'subclass': 'Q5119_столица,Q1637706_город-миллионер,Q7574799_special city of South Korea,'}
# {'entity_id': 'Q31678437', 'entity_label': 'Гора Карпаты', 'subclass': 'Q8502_гора,'}
# {'entity_id': 'Q31678437', 'entity_label': 'Гора Карпаты', 'subclass': 'Q8502_гора,'}
# {'entity_id': 'Q4332610', 'entity_label': 'ОКО', 'subclass': 'Q1497364_комплекс зданий,'}
# {'entity_id': 'Q59483', 'entity_label': 'Меркурий Сити Тауэр', 'subclass': 'Q11303_небоскрёб,'}
# {'entity_id': 'Q4332610', 'entity_label': 'ОКО', 'subclass': 'Q1497364_комплекс зданий,'}
# {'entity_id': 'Q2298717', 'entity_label': 'Мечеть Джумейра', 'subclass': 'Q32815_мечеть,'}
# {'entity_id': 'Q2155757', 'entity_label': 'Маньпупунёр', 'subclass': 'Q631305_скальные образования,Q1959314_особо охраняемая природная территория России,'}
# {'entity_id': 'Q2594129', 'entity_label': 'James Bruce Falls', 'subclass': 'Q34038_водопад,'}
# {'entity_id': 'Q869807', 'entity_label': 'Гаванский Христос', 'subclass': 'Q29168169_колоссальная статуя Иисуса Христа,'}
# {'entity_id': 'Q1128327', 'entity_label': 'Пирамида Кукулькана', 'subclass': 'Q12516_пирамида,'}
# {'entity_id': 'Q597', 'entity_label': 'Лиссабон', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q13217644_муниципалитет Португалии,Q15647906_город Португалии,'}
# {'entity_id': 'Q1353643', 'entity_label': 'Ласточкино гнездо', 'subclass': 'Q180174_Каприз,Q2319498_памятник архитектуры,'}
# {'entity_id': 'Q1548655', 'entity_label': 'Большой Будда на Пхукете', 'subclass': 'Q1000809_Статуи Будды,Q1779653_колоссальная статуя,'}
# {'entity_id': 'Q899', 'entity_label': 'Суэцкий канал', 'subclass': 'Q949819_судоходный канал,'}
# {'entity_id': 'Q23538', 'entity_label': 'Экватор', 'subclass': 'Q146591_Параллель,'}
# {'entity_id': 'Q23883', 'entity_label': 'Мёртвое море', 'subclass': 'Q2912558_сверхсолёное озеро,Q9019918_бессточное озеро,'}
# {'entity_id': 'Q128102', 'entity_label': 'Иртыш', 'subclass': 'Q4366834_Пограничная река,'}
# {'entity_id': 'Q5484', 'entity_label': 'Каспийское море', 'subclass': 'Q15324_водный объект,Q188025_минеральное озеро,Q9019918_бессточное озеро,'}
# {'entity_id': 'Q128102', 'entity_label': 'Иртыш', 'subclass': 'Q4366834_Пограничная река,'}
# {'entity_id': 'Q5595', 'entity_label': 'Куршская коса', 'subclass': 'Q217101_коса,Q1959314_особо охраняемая природная территория России,Q1969226_национальный парк,'}
# {'entity_id': 'Q128102', 'entity_label': 'Иртыш', 'subclass': 'Q4366834_Пограничная река,'}
# {'entity_id': 'Q36288', 'entity_label': 'Великий шёлковый путь', 'subclass': 'Q405155_торговый путь,'}
# {'entity_id': 'Q1489', 'entity_label': 'Мехико', 'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q20528428_federative entity of Mexico,'}
# {'entity_id': 'Q5401', 'entity_label': 'Евразия', 'subclass': 'Q55833_суперконтинент,'}
# {'entity_id': 'Q32099', 'entity_label': 'меридиан', 'subclass': ''}
# {'entity_id': 'Q130905', 'entity_label': 'Гольфстрим', 'subclass': 'Q129558_морское течение,'}
# {'entity_id': 'Q545', 'entity_label': 'Балтийское море', 'subclass': 'Q204894_Окраинное море,Q986177_внутреннее море,'}
# {'entity_id': 'Q5401', 'entity_label': 'Евразия', 'subclass': 'Q55833_суперконтинент,'}
# {'entity_id': 'Q5484', 'entity_label': 'Каспийское море', 'subclass': 'Q15324_водный объект,Q188025_минеральное озеро,Q9019918_бессточное озеро,'}
# {'entity_id': 'Q134485', 'entity_label': 'Балхаш', 'subclass': 'Q9019918_бессточное озеро,'}
# {'entity_id': 'Q35883', 'entity_label': 'Аральское море', 'subclass': 'Q47486890_бывшее озеро,'}
# {'entity_id': 'Q37495', 'entity_label': 'Ионическое море', 'subclass': 'Q204894_Окраинное море,'}
# {'entity_id': 'Q128102', 'entity_label': 'Иртыш', 'subclass': 'Q4366834_Пограничная река,'}
# {'entity_id': 'Q5484', 'entity_label': 'Каспийское море', 'subclass': 'Q15324_водный объект,Q188025_минеральное озеро,Q9019918_бессточное озеро,'}
# {'entity_id': 'Q5484', 'entity_label': 'Каспийское море', 'subclass': 'Q15324_водный объект,Q188025_минеральное озеро,Q9019918_бессточное озеро,'}
# {'entity_id': 'Q23538', 'entity_label': 'Экватор', 'subclass': 'Q146591_Параллель,'}
# {'entity_id': 'Q375029', 'entity_label': 'Рыбинское водохранилище', 'subclass': 'Q131681_водохранилище,'}
# {'entity_id': 'Q1412685', 'entity_label': 'Большой Арктический заповедник', 'subclass': 'Q1484173_заповедник,Q1959314_особо охраняемая природная территория России,'}
# {'entity_id': 'Q134485', 'entity_label': 'Балхаш', 'subclass': 'Q9019918_бессточное озеро,'}
# {'entity_id': 'Q23538', 'entity_label': 'Экватор', 'subclass': 'Q146591_Параллель,'}
# {'entity_id': 'Q2652980', 'entity_label': 'Крымский мост', 'subclass': 'Q537127_автомобильный мост,Q1210334_железнодорожный мост,'}
# {'entity_id': 'Q58767', 'entity_label': 'Транссибирская магистраль', 'subclass': 'Q728937_железнодорожная линия,Q1363599_пассажирский поезд,'}
# {'entity_id': 'Q899', 'entity_label': 'Суэцкий канал', 'subclass': 'Q949819_судоходный канал,'}
# {'entity_id': 'Q2652980', 'entity_label': 'Крымский мост', 'subclass': 'Q537127_автомобильный мост,Q1210334_железнодорожный мост,'}
# {'entity_id': 'Q58767', 'entity_label': 'Транссибирская магистраль', 'subclass': 'Q728937_железнодорожная линия,Q1363599_пассажирский поезд,'}
# {'entity_id': 'Q2372442', 'entity_label': 'Большая Курильская гряда', 'subclass': 'Q667575_Гряда,Q740445_кряж,'}
# {'entity_id': 'Q23538', 'entity_label': 'Экватор', 'subclass': 'Q146591_Параллель,'}
# {'entity_id': 'Q382500', 'entity_label': 'Невский проспект', 'subclass': 'Q907698_проспект,Q8346700_объект культурного наследия России,'}
# {'entity_id': 'Q23538', 'entity_label': 'Экватор', 'subclass': 'Q146591_Параллель,'}
# {'entity_id': 'Q1165682', 'entity_label': 'Европейский маршрут E95', 'subclass': 'Q34442_дорога,'}
# {'entity_id': 'Q128102', 'entity_label': 'Иртыш', 'subclass': 'Q4366834_Пограничная река,'}
# {'entity_id': 'Q23538', 'entity_label': 'Экватор', 'subclass': 'Q146591_Параллель,'}
# {'entity_id': 'Q23538', 'entity_label': 'Экватор', 'subclass': 'Q146591_Параллель,'}
# {'entity_id': 'Q23538', 'entity_label': 'Экватор', 'subclass': 'Q146591_Параллель,'}
# {'entity_id': 'Q17057172', 'entity_label': 'Лесной массив', 'subclass': ''}
# {'entity_id': 'Q11292', 'entity_label': 'коралловый риф', 'subclass': ''}
# {'entity_id': 'Q475050', 'entity_label': 'федеральный округ', 'subclass': 'Q15617994_тип административно-территориальной единицы,'}
# {'entity_id': 'Q3947', 'entity_label': 'дом', 'subclass': ''}
# {'entity_id': 'Q93352', 'entity_label': 'побережье', 'subclass': 'Q25894868_тип места,'}
# {'entity_id': 'Q41176', 'entity_label': 'здание', 'subclass': ''}
# {'entity_id': 'Q337567', 'entity_label': 'водоём', 'subclass': ''}
# {'entity_id': 'Q483110', 'entity_label': 'стадион', 'subclass': ''}
# {'entity_id': 'Q179049', 'entity_label': 'заповедник', 'subclass': ''}
# {'entity_id': 'Q11303', 'entity_label': 'небоскрёб', 'subclass': ''}
# {'entity_id': 'Q486972', 'entity_label': 'населённый пункт', 'subclass': ''}
# {'entity_id': 'Q179049', 'entity_label': 'заповедник', 'subclass': ''}
# {'entity_id': 'Q11292', 'entity_label': 'коралловый риф', 'subclass': ''}
# {'entity_id': 'Q88480', 'entity_label': 'Ров', 'subclass': ''}
# {'entity_id': 'Q15310171', 'entity_label': 'seaport', 'subclass': ''}
# {'entity_id': 'Q5119', 'entity_label': 'столица', 'subclass': ''}
# {'entity_id': 'Q131681', 'entity_label': 'водохранилище', 'subclass': ''}
# {'entity_id': 'Q30198', 'entity_label': 'болото', 'subclass': ''}
# {'entity_id': 'Q131681', 'entity_label': 'водохранилище', 'subclass': ''}
# {'entity_id': 'Q24354', 'entity_label': 'здание театра', 'subclass': ''}
# {'entity_id': 'Q47089', 'entity_label': 'разлом', 'subclass': 'Q334823_структурная геология,'}
# {'entity_id': 'Q79007', 'entity_label': 'улица', 'subclass': ''}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q193071', 'entity_label': 'низменность', 'subclass': 'Q12060061_тип георельефа,'}
# {'entity_id': 'Q55674403', 'entity_label': 'cleft', 'subclass': ''}
# {'entity_id': 'Q55075651', 'entity_label': 'возвышенность', 'subclass': ''}
# {'entity_id': 'Q285451', 'entity_label': 'речная система', 'subclass': ''}
# {'entity_id': 'Q2977', 'entity_label': 'кафедральный собор', 'subclass': ''}
# {'entity_id': 'Q41176', 'entity_label': 'здание', 'subclass': ''}
# {'entity_id': 'Q15310171', 'entity_label': 'seaport', 'subclass': ''}
# {'entity_id': 'Q75520', 'entity_label': 'плато', 'subclass': ''}
# {'entity_id': 'Q55818', 'entity_label': 'ударный кратер', 'subclass': ''}
# {'entity_id': 'Q179049', 'entity_label': 'заповедник', 'subclass': ''}
# {'entity_id': 'Q112099', 'entity_label': 'островное государство', 'subclass': ''}
# {'entity_id': 'Q55818', 'entity_label': 'ударный кратер', 'subclass': ''}
# {'entity_id': 'Q193071', 'entity_label': 'низменность', 'subclass': 'Q12060061_тип георельефа,'}
# {'entity_id': 'Q179049', 'entity_label': 'заповедник', 'subclass': ''}
# {'entity_id': 'Q193071', 'entity_label': 'низменность', 'subclass': 'Q12060061_тип георельефа,'}
# {'entity_id': 'Q15324', 'entity_label': 'водный объект', 'subclass': ''}
# {'entity_id': 'Q43483', 'entity_label': 'колодец', 'subclass': ''}
# {'entity_id': 'Q188040', 'entity_label': 'карьер', 'subclass': ''}
# {'entity_id': 'Q1501', 'entity_label': 'плавательный бассейн', 'subclass': ''}
# {'entity_id': 'Q5503', 'entity_label': 'метрополитен', 'subclass': ''}
# {'entity_id': 'Q44377', 'entity_label': 'тоннель', 'subclass': ''}
# {'entity_id': 'Q44377', 'entity_label': 'тоннель', 'subclass': ''}
# {'entity_id': 'Q88480', 'entity_label': 'Ров', 'subclass': ''}
# {'entity_id': 'Q107679', 'entity_label': 'клиф', 'subclass': ''}
# {'entity_id': 'Q811364', 'entity_label': 'Котлован', 'subclass': ''}
# {'entity_id': 'Q1501', 'entity_label': 'плавательный бассейн', 'subclass': ''}
# {'entity_id': 'Q381885', 'entity_label': 'гробница', 'subclass': ''}
# {'entity_id': 'Q47089', 'entity_label': 'разлом', 'subclass': 'Q334823_структурная геология,'}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q502102', 'entity_label': 'скважина', 'subclass': ''}
# {'entity_id': 'Q928830', 'entity_label': 'станция метрополитена', 'subclass': ''}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q188734', 'entity_label': 'карстовая воронка', 'subclass': ''}
# {'entity_id': 'Q2042028', 'entity_label': 'ущелье', 'subclass': ''}
# {'entity_id': 'Q131681', 'entity_label': 'водохранилище', 'subclass': ''}
# {'entity_id': 'Q5503', 'entity_label': 'метрополитен', 'subclass': ''}
# {'entity_id': 'Q107679', 'entity_label': 'клиф', 'subclass': ''}
# {'entity_id': 'Q44377', 'entity_label': 'тоннель', 'subclass': ''}
# {'entity_id': 'Q468469', 'entity_label': 'Океанское дно', 'subclass': ''}
# {'entity_id': 'Q43483', 'entity_label': 'колодец', 'subclass': ''}
# {'entity_id': 'Q2220733', 'entity_label': 'sand mine', 'subclass': ''}
# {'entity_id': 'Q5503', 'entity_label': 'метрополитен', 'subclass': ''}
# {'entity_id': 'Q131681', 'entity_label': 'водохранилище', 'subclass': ''}
# {'entity_id': 'Q2042028', 'entity_label': 'ущелье', 'subclass': ''}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q502102', 'entity_label': 'скважина', 'subclass': ''}
# {'entity_id': 'Q928830', 'entity_label': 'станция метрополитена', 'subclass': ''}
# {'entity_id': 'Q4232315', 'entity_label': 'шахта', 'subclass': ''}
# {'entity_id': 'Q2042028', 'entity_label': 'ущелье', 'subclass': ''}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q502102', 'entity_label': 'скважина', 'subclass': ''}
# {'entity_id': 'Q15324', 'entity_label': 'водный объект', 'subclass': ''}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q187223', 'entity_label': 'лагуна', 'subclass': ''}
# {'entity_id': 'Q4232315', 'entity_label': 'шахта', 'subclass': ''}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q468469', 'entity_label': 'Океанское дно', 'subclass': ''}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q587682', 'entity_label': 'Нефтяная скважина', 'subclass': ''}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q109391', 'entity_label': 'вулканический кратер', 'subclass': ''}
# {'entity_id': 'Q2220733', 'entity_label': 'sand mine', 'subclass': ''}
# {'entity_id': 'Q2221906', 'entity_label': 'географическое местоположение', 'subclass': 'Q937228_свойство,Q66747521_географический термин,'}
# {'entity_id': 'Q1501', 'entity_label': 'плавательный бассейн', 'subclass': ''}
# {'entity_id': 'Q2220733', 'entity_label': 'sand mine', 'subclass': ''}
# {'entity_id': 'Q468469', 'entity_label': 'Океанское дно', 'subclass': ''}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q15324', 'entity_label': 'водный объект', 'subclass': ''}
# {'entity_id': 'Q2221906', 'entity_label': 'географическое местоположение', 'subclass': 'Q937228_свойство,Q66747521_географический термин,'}
# {'entity_id': 'Q44377', 'entity_label': 'тоннель', 'subclass': ''}
# {'entity_id': 'Q1069932', 'entity_label': 'подводная котловина', 'subclass': ''}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q5503', 'entity_label': 'метрополитен', 'subclass': ''}
# {'entity_id': 'Q2221906', 'entity_label': 'географическое местоположение', 'subclass': 'Q937228_свойство,Q66747521_географический термин,'}
# {'entity_id': 'Q44377', 'entity_label': 'тоннель', 'subclass': ''}
# {'entity_id': 'Q15324', 'entity_label': 'водный объект', 'subclass': ''}
# {'entity_id': 'Q109391', 'entity_label': 'вулканический кратер', 'subclass': ''}
# {'entity_id': 'Q2220733', 'entity_label': 'sand mine', 'subclass': ''}
# {'entity_id': 'Q30198', 'entity_label': 'болото', 'subclass': ''}
# {'entity_id': 'Q131681', 'entity_label': 'водохранилище', 'subclass': ''}
# {'entity_id': 'Q188040', 'entity_label': 'карьер', 'subclass': ''}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q2220733', 'entity_label': 'sand mine', 'subclass': ''}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q2220733', 'entity_label': 'sand mine', 'subclass': ''}
# {'entity_id': 'Q2220733', 'entity_label': 'sand mine', 'subclass': ''}
# {'entity_id': 'Q2220733', 'entity_label': 'sand mine', 'subclass': ''}
# {'entity_id': 'Q188025', 'entity_label': 'минеральное озеро', 'subclass': ''}
# {'entity_id': 'Q2221906', 'entity_label': 'географическое местоположение', 'subclass': 'Q937228_свойство,Q66747521_географический термин,'}
# {'entity_id': 'Q2221906', 'entity_label': 'географическое местоположение', 'subclass': 'Q937228_свойство,Q66747521_географический термин,'}
# {'entity_id': 'Q2221906', 'entity_label': 'географическое местоположение', 'subclass': 'Q937228_свойство,Q66747521_географический термин,'}
# {'entity_id': 'Q813672', 'entity_label': 'впадина', 'subclass': 'Q101072_определение понятия,'}
# {'entity_id': 'Q11634', 'entity_label': 'скульптура', 'subclass': 'Q1799072_метод,Q56055944_форма искусства,'}
# {'entity_id': 'Q12518', 'entity_label': 'башня', 'subclass': ''}
# {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''}
# {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''}
# {'entity_id': 'Q179700', 'entity_label': 'статуя', 'subclass': 'Q18783400_жанр скульптуры,'}
# {'entity_id': 'Q12516', 'entity_label': 'пирамида', 'subclass': ''}
# {'entity_id': 'Q1068623', 'entity_label': 'телебашня', 'subclass': ''}
# {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''}
# {'entity_id': 'Q133056', 'entity_label': 'перевал', 'subclass': ''}
# {'entity_id': 'Q11303', 'entity_label': 'небоскрёб', 'subclass': ''}
# {'entity_id': 'Q2046325', 'entity_label': 'Круглый курган', 'subclass': ''}
# {'entity_id': 'Q1330974', 'entity_label': 'список активных вулканов', 'subclass': ''}
# {'entity_id': 'Q39715', 'entity_label': 'маяк', 'subclass': ''}
# {'entity_id': 'Q54050', 'entity_label': 'холм', 'subclass': ''}
# {'entity_id': 'Q944588', 'entity_label': 'Склон', 'subclass': ''}
# {'entity_id': 'Q2977', 'entity_label': 'кафедральный собор', 'subclass': ''}
# {'entity_id': 'Q3947', 'entity_label': 'дом', 'subclass': ''}
# {'entity_id': 'Q1325302', 'entity_label': 'Дремлющие вулканы', 'subclass': ''}
# {'entity_id': 'Q11303', 'entity_label': 'небоскрёб', 'subclass': ''}
# {'entity_id': 'Q39715', 'entity_label': 'маяк', 'subclass': ''}
# {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''}
# {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''}
# {'entity_id': 'Q54050', 'entity_label': 'холм', 'subclass': ''}
# {'entity_id': 'Q12518', 'entity_label': 'башня', 'subclass': ''}
# {'entity_id': 'Q12518', 'entity_label': 'башня', 'subclass': ''}
# {'entity_id': 'Q1068623', 'entity_label': 'телебашня', 'subclass': ''}
# {'entity_id': 'Q179700', 'entity_label': 'статуя', 'subclass': 'Q18783400_жанр скульптуры,'}
# {'entity_id': 'Q1325302', 'entity_label': 'Дремлющие вулканы', 'subclass': ''}
# {'entity_id': 'Q1325302', 'entity_label': 'Дремлющие вулканы', 'subclass': ''}
# {'entity_id': 'Q1330974', 'entity_label': 'список активных вулканов', 'subclass': ''}
# {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''}
# {'entity_id': 'Q11303', 'entity_label': 'небоскрёб', 'subclass': ''}
# {'entity_id': 'Q1281105', 'entity_label': 'Горнолыжная трасса', 'subclass': ''}
# {'entity_id': 'Q54050', 'entity_label': 'холм', 'subclass': ''}
# {'entity_id': 'Q944588', 'entity_label': 'Склон', 'subclass': ''}
# {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''}
# {'entity_id': 'Q878223', 'entity_label': 'нагорье', 'subclass': 'Q107425_ландшафт,Q12060061_тип георельефа,'}
# {'entity_id': 'Q10884', 'entity_label': 'дерево', 'subclass': 'Q55983715_группа организмов, известная по народному названию,'}
# {'entity_id': 'Q41176', 'entity_label': 'здание', 'subclass': ''}
# {'entity_id': 'Q41176', 'entity_label': 'здание', 'subclass': ''}
# {'entity_id': 'Q202570', 'entity_label': 'колесо обозрения', 'subclass': ''}
# {'entity_id': 'Q41176', 'entity_label': 'здание', 'subclass': ''}
# {'entity_id': 'Q75520', 'entity_label': 'плато', 'subclass': ''}
# {'entity_id': 'Q54050', 'entity_label': 'холм', 'subclass': ''}
# {'entity_id': 'Q179700', 'entity_label': 'статуя', 'subclass': 'Q18783400_жанр скульптуры,'}
# {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''}
# {'entity_id': 'Q54050', 'entity_label': 'холм', 'subclass': ''}
# {'entity_id': 'Q618123', 'entity_label': 'географический объект', 'subclass': ''}
# {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''}
# {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''}
# {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''}
# {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''}
# {'entity_id': 'Q10884', 'entity_label': 'дерево', 'subclass': 'Q55983715_группа организмов, известная по народному названию,'}
# {'entity_id': 'Q54050', 'entity_label': 'холм', 'subclass': ''}
# {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''}
# {'entity_id': 'Q11303', 'entity_label': 'небоскрёб', 'subclass': ''}
# {'entity_id': 'Q54050', 'entity_label': 'холм', 'subclass': ''}
# {'entity_id': 'Q11303', 'entity_label': 'небоскрёб', 'subclass': ''}
# {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''}
# {'entity_id': 'Q41176', 'entity_label': 'здание', 'subclass': ''}
# {'entity_id': 'Q41176', 'entity_label': 'здание', 'subclass': ''}
# {'entity_id': 'Q811979', 'entity_label': 'сооружение', 'subclass': ''}
# {'entity_id': 'Q179700', 'entity_label': 'статуя', 'subclass': 'Q18783400_жанр скульптуры,'}
# {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''}
# {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''}
# {'entity_id': 'Q179700', 'entity_label': 'статуя', 'subclass': 'Q18783400_жанр скульптуры,'}
# {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''}
# {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''}
# {'entity_id': 'Q149621', 'entity_label': 'дистрикт', 'subclass': 'Q15617994_тип административно-территориальной единицы,'}
# ...
#   'subclass': ''},
#  {'entity_id': 'Q1330974',
#   'entity_label': 'список активных вулканов',
#   'subclass': ''},
#  {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''},
#  {'entity_id': 'Q11303', 'entity_label': 'небоскрёб', 'subclass': ''},
#  {'entity_id': 'Q1281105',
#   'entity_label': 'Горнолыжная трасса',
#   'subclass': ''},
#  {'entity_id': 'Q54050', 'entity_label': 'холм', 'subclass': ''},
#  {'entity_id': 'Q944588', 'entity_label': 'Склон', 'subclass': ''},
#  {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''},
#  {'entity_id': 'Q878223',
#   'entity_label': 'нагорье',
#   'subclass': 'Q107425_ландшафт,Q12060061_тип георельефа,'},
#  {'entity_id': 'Q10884',
#   'entity_label': 'дерево',
#   'subclass': 'Q55983715_группа организмов, известная по народному названию,'},
#  {'entity_id': 'Q41176', 'entity_label': 'здание', 'subclass': ''},
#  {'entity_id': 'Q41176', 'entity_label': 'здание', 'subclass': ''},
#  {'entity_id': 'Q202570', 'entity_label': 'колесо обозрения', 'subclass': ''},
#  {'entity_id': 'Q41176', 'entity_label': 'здание', 'subclass': ''},
#  {'entity_id': 'Q75520', 'entity_label': 'плато', 'subclass': ''},
#  {'entity_id': 'Q54050', 'entity_label': 'холм', 'subclass': ''},
#  {'entity_id': 'Q179700',
#   'entity_label': 'статуя',
#   'subclass': 'Q18783400_жанр скульптуры,'},
#  {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''},
#  {'entity_id': 'Q54050', 'entity_label': 'холм', 'subclass': ''},
#  {'entity_id': 'Q618123',
#   'entity_label': 'географический объект',
#   'subclass': ''},
#  {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''},
#  {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''},
#  {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''},
#  {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''},
#  {'entity_id': 'Q10884',
#   'entity_label': 'дерево',
#   'subclass': 'Q55983715_группа организмов, известная по народному названию,'},
#  {'entity_id': 'Q54050', 'entity_label': 'холм', 'subclass': ''},
#  {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''},
#  {'entity_id': 'Q11303', 'entity_label': 'небоскрёб', 'subclass': ''},
#  {'entity_id': 'Q54050', 'entity_label': 'холм', 'subclass': ''},
#  {'entity_id': 'Q11303', 'entity_label': 'небоскрёб', 'subclass': ''},
#  {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''},
#  {'entity_id': 'Q41176', 'entity_label': 'здание', 'subclass': ''},
#  {'entity_id': 'Q41176', 'entity_label': 'здание', 'subclass': ''},
#  {'entity_id': 'Q811979', 'entity_label': 'сооружение', 'subclass': ''},
#  {'entity_id': 'Q179700',
#   'entity_label': 'статуя',
#   'subclass': 'Q18783400_жанр скульптуры,'},
#  {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''},
#  {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''},
#  {'entity_id': 'Q179700',
#   'entity_label': 'статуя',
#   'subclass': 'Q18783400_жанр скульптуры,'},
#  {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''},
#  {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''},
#  {'entity_id': 'Q149621',
#   'entity_label': 'дистрикт',
#   'subclass': 'Q15617994_тип административно-территориальной единицы,'},
#  {'entity_id': 'Q1330974',
#   'entity_label': 'список активных вулканов',
#   'subclass': ''},
#  {'entity_id': 'Q41176', 'entity_label': 'здание', 'subclass': ''},
#  {'entity_id': 'Q41176', 'entity_label': 'здание', 'subclass': ''},
#  {'entity_id': 'Q41176', 'entity_label': 'здание', 'subclass': ''},
#  {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''},
#  {'entity_id': 'Q41176', 'entity_label': 'здание', 'subclass': ''},
#  {'entity_id': 'Q54050', 'entity_label': 'холм', 'subclass': ''},
#  {'entity_id': 'Q75520', 'entity_label': 'плато', 'subclass': ''},
#  {'entity_id': 'Q41176', 'entity_label': 'здание', 'subclass': ''},
#  {'entity_id': 'Q54050', 'entity_label': 'холм', 'subclass': ''},
#  {'entity_id': 'Q811979', 'entity_label': 'сооружение', 'subclass': ''},
#  {'entity_id': 'Q75520', 'entity_label': 'плато', 'subclass': ''},
#  {'entity_id': 'Q41176', 'entity_label': 'здание', 'subclass': ''},
#  {'entity_id': 'Q3257686',
#   'entity_label': 'обжитая местность',
#   'subclass': 'Q48907157_часть населённого пункта,'},
#  {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''},
#  {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''},
#  {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''},
#  {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''},
#  {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''},
#  {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''},
#  {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''},
#  {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''},
#  {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''},
#  {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''},
#  {'entity_id': 'Q3393392', 'entity_label': 'наивысшая точка', 'subclass': ''},
#  {'entity_id': 'Q1325302',
#   'entity_label': 'Дремлющие вулканы',
#   'subclass': ''},
#  {'entity_id': 'Q44377', 'entity_label': 'тоннель', 'subclass': ''},
#  {'entity_id': 'Q134851', 'entity_label': 'Шельф', 'subclass': ''},
#  {'entity_id': 'Q63565252', 'entity_label': 'ручей', 'subclass': ''},
#  {'entity_id': 'Q44377', 'entity_label': 'тоннель', 'subclass': ''},
#  {'entity_id': 'Q93267', 'entity_label': 'перешеек', 'subclass': ''},
#  {'entity_id': 'Q93352',
#   'entity_label': 'побережье',
#   'subclass': 'Q25894868_тип места,'},
#  {'entity_id': 'Q12570',
#   'entity_label': 'висячий мост',
#   'subclass': 'Q17644823_bridge by structural type,'},
#  {'entity_id': 'Q15921555', 'entity_label': 'рейс', 'subclass': ''},
#  {'entity_id': 'Q11292', 'entity_label': 'коралловый риф', 'subclass': ''},
#  {'entity_id': 'Q159675', 'entity_label': 'приток', 'subclass': ''},
#  {'entity_id': 'Q3947', 'entity_label': 'дом', 'subclass': ''},
#  {'entity_id': 'Q188040', 'entity_label': 'карьер', 'subclass': ''},
#  {'entity_id': 'Q23384', 'entity_label': 'прилив и отлив', 'subclass': ''},
#  {'entity_id': 'Q863454', 'entity_label': 'пирс', 'subclass': ''},
#  {'entity_id': 'Q40080', 'entity_label': 'пляж', 'subclass': ''},
#  {'entity_id': 'Q47089',
#   'entity_label': 'разлом',
#   'subclass': 'Q334823_структурная геология,'},
#  {'entity_id': 'Q133056', 'entity_label': 'перевал', 'subclass': ''},
#  {'entity_id': 'Q7543083', 'entity_label': 'авеню', 'subclass': ''},
#  {'entity_id': 'Q949819', 'entity_label': 'судоходный канал', 'subclass': ''},
#  {'entity_id': 'Q34442', 'entity_label': 'дорога', 'subclass': ''},
#  {'entity_id': 'Q107679', 'entity_label': 'клиф', 'subclass': ''},
#  {'entity_id': 'Q34442', 'entity_label': 'дорога', 'subclass': ''},
#  {'entity_id': 'Q79007', 'entity_label': 'улица', 'subclass': ''},
#  {'entity_id': 'Q1701967', 'entity_label': 'береговая линия', 'subclass': ''},
#  {'entity_id': 'Q46622',
#   'entity_label': 'автомагистраль',
#   'subclass': 'Q7860962_road type,'},
#  {'entity_id': 'Q269949',
#   'entity_label': 'шоссе',
#   'subclass': 'Q7860962_road type,'},
#  {'entity_id': 'Q22667', 'entity_label': 'железная дорога', 'subclass': ''},
#  {'entity_id': 'Q34027',
#   'entity_label': 'широта',
#   'subclass': 'Q22664_географические координаты,'},
#  {'entity_id': 'Q13409250', 'entity_label': 'канатная дорога', 'subclass': ''},
#  {'entity_id': 'Q34442', 'entity_label': 'дорога', 'subclass': ''},
#  {'entity_id': 'Q813672',
#   'entity_label': 'впадина',
#   'subclass': 'Q101072_определение понятия,'},
#  {'entity_id': 'Q44377', 'entity_label': 'тоннель', 'subclass': ''},
#  {'entity_id': 'Q93267', 'entity_label': 'перешеек', 'subclass': ''},
#  {'entity_id': 'Q949819', 'entity_label': 'судоходный канал', 'subclass': ''},
#  {'entity_id': 'Q15324', 'entity_label': 'водный объект', 'subclass': ''},
#  {'entity_id': 'Q17057172', 'entity_label': 'Лесной массив', 'subclass': ''},
#  {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''},
#  {'entity_id': 'Q40080', 'entity_label': 'пляж', 'subclass': ''},
#  {'entity_id': 'Q44377', 'entity_label': 'тоннель', 'subclass': ''},
#  {'entity_id': 'Q46622',
#   'entity_label': 'автомагистраль',
#   'subclass': 'Q7860962_road type,'},
#  {'entity_id': 'Q79007', 'entity_label': 'улица', 'subclass': ''},
#  {'entity_id': 'Q34442', 'entity_label': 'дорога', 'subclass': ''},
#  {'entity_id': 'Q46622',
#   'entity_label': 'автомагистраль',
#   'subclass': 'Q7860962_road type,'},
#  {'entity_id': 'Q813672',
#   'entity_label': 'впадина',
#   'subclass': 'Q101072_определение понятия,'},
#  {'entity_id': 'Q34442', 'entity_label': 'дорога', 'subclass': ''},
#  {'entity_id': 'Q129558', 'entity_label': 'морское течение', 'subclass': ''},
#  {'entity_id': 'Q5503', 'entity_label': 'метрополитен', 'subclass': ''},
#  {'entity_id': 'Q2042028', 'entity_label': 'ущелье', 'subclass': ''},
#  {'entity_id': 'Q269949',
#   'entity_label': 'шоссе',
#   'subclass': 'Q7860962_road type,'},
#  {'entity_id': 'Q28195494',
#   'entity_label': 'течение',
#   'subclass': 'Q3249551_процесс,'},
#  {'entity_id': 'Q2042028', 'entity_label': 'ущелье', 'subclass': ''},
#  {'entity_id': 'Q269949',
#   'entity_label': 'шоссе',
#   'subclass': 'Q7860962_road type,'},
#  {'entity_id': 'Q269949',
#   'entity_label': 'шоссе',
#   'subclass': 'Q7860962_road type,'},
#  {'entity_id': 'Q44377', 'entity_label': 'тоннель', 'subclass': ''},
#  {'entity_id': 'Q160342',
#   'entity_label': 'железнодорожный путь',
#   'subclass': ''},
#  {'entity_id': 'Q28575',
#   'entity_label': 'графство',
#   'subclass': 'Q15617994_тип административно-территориальной единицы,'},
#  {'entity_id': 'Q40080', 'entity_label': 'пляж', 'subclass': ''},
#  {'entity_id': 'Q44377', 'entity_label': 'тоннель', 'subclass': ''},
#  {'entity_id': 'Q34442', 'entity_label': 'дорога', 'subclass': ''},
#  {'entity_id': 'Q11292', 'entity_label': 'коралловый риф', 'subclass': ''},
#  {'entity_id': 'Q79007', 'entity_label': 'улица', 'subclass': ''},
#  {'entity_id': 'Q40080', 'entity_label': 'пляж', 'subclass': ''},
#  {'entity_id': 'Q93352',
#   'entity_label': 'побережье',
#   'subclass': 'Q25894868_тип места,'},
#  {'entity_id': 'Q93352',
#   'entity_label': 'побережье',
#   'subclass': 'Q25894868_тип места,'},
#  {'entity_id': 'Q149621',
#   'entity_label': 'дистрикт',
#   'subclass': 'Q15617994_тип административно-территориальной единицы,'},
#  {'entity_id': 'Q23413',
#   'entity_label': 'замок',
#   'subclass': 'Q41176_здание,'},
#  {'entity_id': 'Q3947', 'entity_label': 'дом', 'subclass': ''},
#  {'entity_id': 'Q24489', 'entity_label': 'ископаемый уголь', 'subclass': ''},
#  {'entity_id': 'Q486972', 'entity_label': 'населённый пункт', 'subclass': ''},
#  {'entity_id': 'Q43742', 'entity_label': 'оазис', 'subclass': ''},
#  {'entity_id': 'Q2983893',
#   'entity_label': 'квартал',
#   'subclass': 'Q15617994_тип административно-территориальной единицы,'},
#  {'entity_id': 'Q156030', 'entity_label': 'Лиман', 'subclass': ''},
#  {'entity_id': 'Q179049', 'entity_label': 'заповедник', 'subclass': ''},
#  {'entity_id': 'Q2023000',
#   'entity_label': 'хутор',
#   'subclass': 'Q56061_административно-территориальная единица,'},
#  {'entity_id': 'Q17057172', 'entity_label': 'Лесной массив', 'subclass': ''},
#  {'entity_id': 'Q5084', 'entity_label': 'деревня', 'subclass': ''},
#  {'entity_id': 'Q5119', 'entity_label': 'столица', 'subclass': ''},
#  {'entity_id': 'Q75520', 'entity_label': 'плато', 'subclass': ''},
#  {'entity_id': 'Q188025', 'entity_label': 'минеральное озеро', 'subclass': ''},
#  {'entity_id': 'Q986177', 'entity_label': 'внутреннее море', 'subclass': ''},
#  {'entity_id': 'Q112099',
#   'entity_label': 'островное государство',
#   'subclass': ''},
#  {'entity_id': 'Q5283',
#   'entity_label': 'алмаз',
#   'subclass': 'Q12089225_действительный вид минералов,'},
#  {'entity_id': 'Q2738486',
#   'entity_label': 'край',
#   'subclass': 'Q15617994_тип административно-территориальной единицы,'},
#  {'entity_id': 'Q4946461', 'entity_label': 'курорт', 'subclass': ''},
#  {'entity_id': 'Q43742', 'entity_label': 'оазис', 'subclass': ''},
#  {'entity_id': 'Q3947', 'entity_label': 'дом', 'subclass': ''},
#  {'entity_id': 'Q207326', 'entity_label': 'вершина местности', 'subclass': ''},
#  {'entity_id': 'Q486972', 'entity_label': 'населённый пункт', 'subclass': ''},
#  {'entity_id': 'Q193071',
#   'entity_label': 'низменность',
#   'subclass': 'Q12060061_тип георельефа,'},
#  {'entity_id': 'Q2738486',
#   'entity_label': 'край',
#   'subclass': 'Q15617994_тип административно-территориальной единицы,'},
#  {'entity_id': 'Q5119', 'entity_label': 'столица', 'subclass': ''},
#  {'entity_id': 'Q16970', 'entity_label': 'храм', 'subclass': ''},
#  {'entity_id': 'Q79007', 'entity_label': 'улица', 'subclass': ''},
#  {'entity_id': 'Q43197', 'entity_label': 'дельта реки', 'subclass': ''},
#  {'entity_id': 'Q7270',
#   'entity_label': 'республика',
#   'subclass': 'Q183039_форма государственного устройства,Q1307214_форма государственного правления,'},
#  {'entity_id': 'Q223',
#   'entity_label': 'Гренландия',
#   'subclass': 'Q192611_избирательный округ,Q66724388_страна в составе Королевства Дании,'},
#  {'entity_id': 'Q223',
#   'entity_label': 'Гренландия',
#   'subclass': 'Q192611_избирательный округ,Q66724388_страна в составе Королевства Дании,'},
#  {'entity_id': 'Q85', 'entity_label': 'Каир', 'subclass': 'Q5119_столица,'},
#  {'entity_id': 'Q8652',
#   'entity_label': 'Майами',
#   'subclass': 'Q1093829_большой город в США,'},
#  {'entity_id': 'Q23768',
#   'entity_label': 'Лас-Вегас',
#   'subclass': 'Q56061_административно-территориальная единица,Q1093829_большой город в США,Q1549591_город с населением более 100 000 человек,'},
#  {'entity_id': 'Q223',
#   'entity_label': 'Гренландия',
#   'subclass': 'Q192611_избирательный округ,Q66724388_страна в составе Королевства Дании,'},
#  {'entity_id': 'Q1353',
#   'entity_label': 'Дели',
#   'subclass': 'Q174844_мега-город,Q467745_союзные территории Индии,Q1637706_город-миллионер,'},
#  {'entity_id': 'Q409102',
#   'entity_label': 'Никопол',
#   'subclass': 'Q902814_граничный город,Q15303838_местоположение муниципалитета,Q89487741_город в Болгарии,'},
#  {'entity_id': 'Q223',
#   'entity_label': 'Гренландия',
#   'subclass': 'Q192611_избирательный округ,Q66724388_страна в составе Королевства Дании,'},
#  {'entity_id': 'Q1930',
#   'entity_label': 'Оттава',
#   'subclass': 'Q5119_столица,Q486972_населённый пункт,Q1549591_город с населением более 100 000 человек,Q14762300_одноуровневый муниципалитет Онтарио,Q17457753_census subdivision,'},
#  {'entity_id': 'Q500895',
#   'entity_label': 'Тикси',
#   'subclass': 'Q192287_административно-территориальная единица России,Q15078955_посёлок городского типа России,'},
#  {'entity_id': 'Q4218839',
#   'entity_label': 'Харьков',
#   'subclass': 'Q7216840_посёлок городского типа Украины,'},
#  {'entity_id': 'Q1874',
#   'entity_label': 'Одесса',
#   'subclass': 'Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q2264924_портовый город,Q5123999_город областного значения Украины,'},
#  {'entity_id': 'Q156747',
#   'entity_label': 'Полтава',
#   'subclass': 'Q5123999_город областного значения Украины,'},
#  {'entity_id': 'Q1953',
#   'entity_label': 'Ереван',
#   'subclass': 'Q5119_столица,Q1549591_город с населением более 100 000 человек,Q1637706_город-миллионер,Q10864048_административная единица первого уровня,Q20724701_город в Армении,'},
#  {'entity_id': 'Q31354462',
#   'entity_label': 'Республика Абхазия',
#   'subclass': 'Q15634554_непризнанное либо частично признанное государство,'},
#  {'entity_id': 'Q5401',
#   'entity_label': 'Евразия',
#   'subclass': 'Q55833_суперконтинент,'},
#  {'entity_id': 'Q4628',
#   'entity_label': 'Фарерские острова',
#   'subclass': 'Q192611_избирательный округ,Q66724388_страна в составе Королевства Дании,'},
#  {'entity_id': 'Q1780477',
#   'entity_label': 'Коммунарка',
#   'subclass': 'Q486972_населённый пункт,Q2514025_посёлок,'},
#  {'entity_id': 'Q855652',
#   'entity_label': 'Сан-Кристобаль',
#   'subclass': 'Q23442_остров,'}]

# %%
f = []
a = []
c = Counter()
for i in not_found:
    c[i] += 1 
count = dict(c)
for i in res:
    if i['entity_id'] in count and not i['entity_id'] in a:
        i['count'] = count[i['entity_id']]
        f.append(i)
        a.append(i['entity_id'])
f = pd.DataFrame(data = f)
f = f[['entity_id','entity_label','count','subclass']]
f.to_excel(r'Final analytics\Other_entities.xlsx', sheet_name = 'by_entities' ,encoding='utf-8-sig' , index = False)

# %%
b = []
for i in res:
    if i['subclass'] != '':
        a = i['subclass'].split(",")
        for j in a:
            if j != '' and not 'известная по народному названию' in j:
                qid = j.split('_')[0]
                label = j.split('_')[1]
                b.append((qid, label))
c = Counter()
for i in b:
    c[i] += 1 
result = []
for k,v in c.items():
    dic = {}
    dic['entity_id'] = k[0]
    dic['subclass'] = k[1]
    dic['count'] = v
    result.append(dic)
df = pd.DataFrame(data = result).sort_values(by = 'count',ascending = False)
with pd.ExcelWriter(r'Final analytics\Other_entities.xlsx' ,  engine="openpyxl" , mode  = 'a') as writer:
        df.to_excel(writer, sheet_name = 'by_subclasses' , encoding='utf-8-sig' , index = False)
